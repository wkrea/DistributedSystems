# %% [markdown]
# In this exercise we will calculate the number of stops within the radius of a specified position.
#
# First we initialise PySpark.

# %%
from pyspark import SparkContext

sc = SparkContext.getOrCreate()

# %% [markdown]
# We first read all the stops. The specified file is a preprocessed version of the JSON "stops.txt", in which
# each line contains one stop in the format
#
# halte_id;halte_name;lat;long;town_name
#
# This makes it easier
# to parse since it only requires a call to str.split().

# %%
stops = sc.textFile("./converted_stops.csv").map(lambda stop: tuple([x.strip() for x in stop.split(";")]))

# %% [markdown]
# In order to determine the amount of stops inside a radius, we first need to
# add the radius and coordinate data to the stops.
#
# The user can select a point by setting the variables "lat", "long" and "radius"
# which specifies the radius in meters.
#
# This is done using a simple map.
# The result is an RDD with tuples of the form (stop, radius, point).

# %%
# these need to be floats!
lat = 51.21989
long = 4.40346
radius = 3000.0 # in meters

stops_with_geodata = stops.map(lambda stop: (stop, radius, (lat, long)))

# %% [markdown]
# Next, we create a function that determines the distance between the specified
# point, and a set of coordinates. We use the function to map the
# (stop, radius, point) tuples to (stop, radius, distance) tuples.
# We then filter the tuples where distance > radius.
#
# Note: since the earth is a sphere euclidian distances are not
# accurate enough, I have used an online implementation of the haversine method.
# http://evoling.net/code/haversine/
# https://stackoverflow.com/questions/4913349/haversine-formula-in-python-bearing-and-distance-between-two-gps-points/4913653#4913653
# There are many sources, I don't know which one is the original.

# %%
def haversine(coord1, coord2):
    from math import radians, cos, sin, asin, sqrt
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    
    lat1, lon1 = coord1
    lat2, lon2 = coord2
    
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2.0)**2.0 + cos(lat1) * cos(lat2) * sin(dlon/2.0)**2.0
    c = 2.0 * asin(sqrt(a)) 
    # Radius of earth in kilometers is 6371
    km = 6371.0 * c
    m = km * 1000.0
    return m

def get_stop_coord(stop):
  """Retrieve the geo coordinate of a stop."""
  return float(stop[2]), float(stop[3])

stop_with_distance = stops_with_geodata.map(lambda x: (x[0], x[1], haversine(get_stop_coord(x[0]), x[2])))
stops_within_radius = stop_with_distance.filter(lambda x: x[1] >= x[2]) # radius >= distance
stop_list = stops_within_radius.collect() # all the stops
stop_count = stops_within_radius.count() # amount of stops

# %% [markdown]
# Finally, we print the result.

# %%
print("{} stops found within radius of {} meters:\n".format(stop_count, radius))
print("Stad - Halte naam - Afstand")
print("---------------------------\n")
for stop in stop_list:
  print("{} - {} - {}".format(stop[0][4].encode('utf-8'), stop[0][1].encode('utf-8'), stop[2]))
# Out:
# 459 stops found within radius of 3000.0 meters:
#
# Stad - Halte naam - Afstand
# ---------------------------
#
# Antwerpen - Zurenborg - 2158.39363984
# Antwerpen - A. Grisarstraat - 2487.26174391
# Antwerpen - A. Van Cauwelaert - 1971.34288902
# Antwerpen - A. Van Cauwelaert - 2004.53944533
# Antwerpen - Straatsburgdok - 2632.41403237
# Antwerpen - Bestorming - 1571.41017311
# Antwerpen - Begijnenvest - 1112.96963604
# Antwerpen - Sint-Jansplein - 1009.95947498
# Antwerpen - Sint-Jansplein - 1042.45534847
# Antwerpen - F. Rooseveltplaats perron 25 - 1001.22774256
# Antwerpen - Cadix - 1479.79224674
# Antwerpen - Stadspark - 864.219171299
# Antwerpen - Ballaarstraat - 1748.31038733
# Antwerpen - Begijnenvest - 1131.42336092
# Antwerpen - Montigny - 1715.09403069
# Antwerpen - Bestorming - 1617.601695
# Antwerpen - Belgiëlei - 1811.9008656
# Antwerpen - Belgiëlei - 1920.76584647
# Berchem - Station perron 21 - 2952.85534202
# Berchem - Station perron 12 - 2962.39782124
# Berchem - Station perron 13 - 2944.84554314
# Berchem - Station perron 14 - 2947.73989315
# Antwerpen - Hemel - 1397.52696523
# Antwerpen - Desguinlei - 2983.57997895
# Antwerpen - Bolivarplaats - 2091.08679516
# Berchem - De Merode - 2505.47440293
# Berchem - Station perron 15 - 2942.28860808
# Berchem - Station perron 24 - 2929.95592491
# Borgerhout - De Roma - 2702.28379737
# Antwerpen - Bres - 1389.46168119
# Antwerpen - Sint-Vincentius - 1599.89537996
# Antwerpen - Broedermin - 2033.97577709
# Antwerpen - Broedermin - 1981.76544029
# Antwerpen - Van Schoonbekeplein - 772.552568645
# Antwerpen - Straatsburgdok - 2644.82206599
# Antwerpen - Van Bree - 1219.83068432
# Antwerpen - Centraal Station perron 6 - 1278.31127639
# Antwerpen - Ferdinanduspolder - 2168.51059117
# Antwerpen - Ferdinanduspolder - 2164.37183794
# Antwerpen - Centraal Station perron 10 - 1242.33219067
# Antwerpen - Bolivarplaats - 2035.43475091
# Antwerpen - Bolivarplaats - 2044.56595822
# Antwerpen - Oudaan - 466.142084936
# Antwerpen - Centraal Station perron 4 - 1197.686277
# Antwerpen - deSingel - 2794.09463005
# Antwerpen - deSingel - 2892.10781704
# Antwerpen - deSingel - 2872.09963472
# Antwerpen - deSingel - 2775.05400884
# Antwerpen - Cuperus - 2511.30193918
# Antwerpen - Dageraadplaats - 2352.27692258
# Antwerpen - Dageraadplaats - 2271.14899029
# Berchem - Station perron 11 - 2965.72191698
# Antwerpen - De Coninck - 1226.7530181
# Antwerpen - De Coninck - 1244.0460812
# Antwerpen - Sportpaleis - 2977.81818984
# Antwerpen - deSingel - 2758.15587516
# Antwerpen - deSingel - 2754.3048483
# Antwerpen - Desguinlei - 2928.18392468
# Antwerpen - Schijnpoort - 2708.75118605
# Antwerpen - Schijnpoort - 2739.04663757
# Antwerpen - Sint-Gummarus - 1414.67613819
# Antwerpen - Diepestraat - 1617.4374847
# Antwerpen - F. Rooseveltplaats perron 52 - 1003.87493747
# Antwerpen - Felixarchief - 885.530244484
# Antwerpen - Draakplaats - 2563.86210216
# Berchem - Draakplaats - 2555.71214377
# Berchem - Draakplaats - 2578.60794229
# Antwerpen - Draakplaats - 2561.86511378
# Berchem - Driekoningen - 2866.90055094
# Borgerhout - Drink - 2266.20477579
# Borgerhout - Drink - 2236.3223417
# Berchem - Station perron 2 - 2947.9304729
# Berchem - Station perron 23 - 2939.202855
# Antwerpen - Pacificatie - 1782.28792879
# Antwerpen - Pacificatie - 1780.9952609
# Antwerpen - Ellermanstraat - 1571.0264133
# Antwerpen - Ellermanstraat - 1581.18832898
# Berchem - De Merode - 2574.51782502
# Antwerpen - F. Rooseveltplaats perron 50 - 1006.34877724
# Antwerpen - F. Rooseveltplaats perron 37 - 916.624483218
# Antwerpen - Waterpoort - 1664.24419125
# Antwerpen - F. Rooseveltplaats perron 30 - 990.362658811
# Antwerpen - F. Rooseveltplaats perron 22 - 991.45412409
# Antwerpen - F. Rooseveltplaats perron 36 - 929.515364954
# Antwerpen - Centraal Station perron 11 - 1232.21643489
# Antwerpen - Lange Kievitstraat - 1413.15341572
# Berchem - Driekoningen - 2922.92715865
# Antwerpen - F. Rooseveltplaats perron 53 - 935.3762641
# Antwerpen - Felixarchief - 865.019699162
# Antwerpen - Fransenplaats - 2153.75952086
# Berchem - A. Grisarstraat - 2501.63175703
# Antwerpen - Fransenplaats - 2170.82533723
# Antwerpen - Rijnkaai - 1146.23848441
# Antwerpen - F. Rooseveltplaats perron 47 - 957.956353915
# Antwerpen - Smallestraat - 2045.04531452
# Antwerpen - Gasstraat - 1638.17941663
# Antwerpen - Gasstraat - 1601.53376923
# Antwerpen - Centraal Station perron 3 - 1219.50833766
# Antwerpen - Centraal Station perron 2 - 1247.4223865
# Antwerpen - Kasteelplein - 1187.99977851
# Antwerpen - Kasteelplein - 1232.87369641
# Antwerpen - Tropisch Instituut - 872.431080916
# Antwerpen - Tropisch Instituut - 962.630178148
# Antwerpen - Gounod - 1640.11779183
# Antwerpen - Gounod - 1670.21721665
# Antwerpen - Groeningerplein - 2423.76325854
# Borgerhout - Groeningerplein - 2405.91854027
# Antwerpen - De Coninck - 1192.99367622
# Antwerpen - Groenplaats - 195.212484239
# Antwerpen - Groenplaats - 211.192727081
# Antwerpen - Groenplaats - 197.673981255
# Antwerpen - Sint-Jansplein - 1134.12822725
# Antwerpen - Lamorinièrestraat - 1972.07913022
# Antwerpen - Lamorinièrestraat - 1996.08914388
# Antwerpen - Sporthal Linkeroever - 2311.04774257
# Antwerpen - Sint-Katelijne - 175.037991481
# Antwerpen - Halenstraat - 2402.92013786
# Antwerpen - Halenstraat - 2380.72863914
# Antwerpen - Handel - 2049.5997312
# Antwerpen - Halewijn - 1667.9858148
# Antwerpen - Halewijn - 1665.87693798
# Antwerpen - Troonplaats - 1907.65977843
# Antwerpen - Handelsteeg - 1853.34867955
# Antwerpen - Harmonie - 2086.82157681
# Antwerpen - Harmonie - 2183.62823163
# Antwerpen - Quellin perron 2 - 950.387373022
# Antwerpen - Cadix - 1534.88753718
# Antwerpen - Harmonie - 2158.29818702
# Antwerpen - Harmonie - 2149.86720783
# Antwerpen - Harmonie - 2134.06961356
# Antwerpen - Lokkaardstraat - 2417.07117126
# Antwerpen - Groenendaallaan - 2953.52515561
# Antwerpen - Provinciehuis - 2355.63077604
# Antwerpen - Provinciehuis - 2442.33825797
# Antwerpen - Haringrodestraat - 2438.19022862
# Antwerpen - Haringrodestraat - 2449.90932254
# Borgerhout - Helmstraat - 2482.45157836
# Antwerpen - Hemel - 1244.57091452
# Antwerpen - Provinciehuis - 2482.15768533
# Berchem - Station perron 1 - 2946.51917427
# Antwerpen - Hessenbrug - 739.975237848
# Antwerpen - Slachthuislaan - 2687.51440548
# Berchem - Driekoningen - 2950.08609776
# Berchem - De Villegasstraat - 2883.90349351
# Berchem - Van Marsenillestraat - 2893.68690576
# Antwerpen - Noorderbrug - 2434.05341242
# Antwerpen - Noorderbrug - 2423.07585104
# Antwerpen - Groenendaallaan - 2941.69220481
# Antwerpen - IJzerlaan - 2106.1745186
# Antwerpen - IJzerlaan - 2125.83563026
# Antwerpen - Rodestraat - 882.06541099
# Antwerpen - Graaf Van Hoornestraat - 1677.80893455
# Antwerpen - Markgravelei - 2615.3154038
# Antwerpen - P+R Linkeroever - 2823.57744591
# Antwerpen - Jezusstraat - 742.212347556
# Antwerpen - Zuid Perron 5 - 2319.43407845
# Antwerpen - Zuid Perron 4 - 2370.67767831
# Borgerhout - Premetrostation Zegel - 2775.22010927
# Antwerpen - Premetrostation Astrid - 1229.52464108
# Antwerpen - Premetrostation Astrid - 1258.08493031
# Borgerhout - Premetrostation Zegel - 2787.34668073
# Berchem - Station perron 3 - 2950.77901474
# Antwerpen - IGLO - 1570.97067242
# Antwerpen - Brouwersvliet - 829.413796516
# Antwerpen - Brouwersvliet - 838.620210786
# Antwerpen - MAS - 1106.01215511
# Antwerpen - MAS - 1106.16287372
# Antwerpen - Zuid Perron 3b - 2387.72281388
# Antwerpen - Zuid Perron 3a - 2383.06379688
# Antwerpen - Zuid Perron 2b - 2378.04472794
# Antwerpen - Zuid Perron 2a - 2373.02598617
# Antwerpen - Zuid Perron 1 - 2368.36969192
# Antwerpen - M HKA - 1367.11102917
# Antwerpen - Quellin - 962.083305244
# Antwerpen - Amsterdam - 1275.06576607
# Antwerpen - Amsterdam - 1249.76730916
# Antwerpen - Londen - 1307.10032646
# Antwerpen - Londen - 1297.91450057
# Antwerpen - Bolivarplaats - 2189.09253357
# Antwerpen - Sint-Paulusplaats - 577.399893525
# Antwerpen - Noorderplaats Perron 3 - 1423.10575456
# Antwerpen - Paardenmarkt - 984.898700757
# Antwerpen - Paardenmarkt - 960.241217196
# Antwerpen - Cuperus - 2507.95057366
# Antwerpen - Cuperus - 2505.41630698
# Antwerpen - Noorderplaats - 1329.17172948
# Antwerpen - Noorderplaats - 1337.84795157
# Antwerpen - Noorderplaats - 1344.89465693
# Antwerpen - Havenhuis - 2308.46849825
# Antwerpen - Havenhuis - 2300.36216821
# Antwerpen - F. Rooseveltplaats - 919.81138007
# Antwerpen - F. Rooseveltplaats - 902.751732507
# Antwerpen - Opera - 869.5041068
# Antwerpen - Opera - 852.438488389
# Antwerpen - Noorderplaats Perron 2 - 1417.9302995
# Antwerpen - Noorderplaats Perron 1 - 1389.14692748
# Antwerpen - Astrid Metro - 1229.52464108
# Antwerpen - Astrid Metro - 1258.17074838
# Antwerpen - Sint-Andries - 594.611355117
# Antwerpen - Kronenburgstraat - 939.274271673
# Antwerpen - Montigny - 1730.60415559
# Antwerpen - Keizerstraat - 248.100698865
# Antwerpen - Kerkstraat - 1648.35447656
# Antwerpen - Kerkstraat - 1783.92153629
# Antwerpen - Klapdorp - 453.890514744
# Antwerpen - Kolonel Silvertop - 2899.48044579
# Antwerpen - Kolonel Silvertop - 2856.96351743
# Antwerpen - Weilandstraat - 2248.59111421
# Antwerpen - Mercatorstraat - 1580.21930425
# Antwerpen - Markgravelei - 2529.49925497
# Antwerpen - Korte Van Bloerstraat - 1941.77680912
# Antwerpen - Centraal Station perron 3 - 1219.50833766
# Antwerpen - Kronenburgstraat - 946.227902145
# Antwerpen - Roosevelt - 919.899401741
# Antwerpen - Lamorinièrestraat - 2020.80398859
# Antwerpen - Lange Kievitstraat - 1423.89037383
# Antwerpen - Klapdorp - 389.444276088
# Antwerpen - Lange Leemstraat - 1849.92448305
# Antwerpen - Lange Leemstraat - 1841.04393497
# Antwerpen - Lange Leemstraat - 1857.39411418
# Antwerpen - Lange Leemstraat - 1868.19368648
# Antwerpen - Cuperus - 2494.04144473
# Antwerpen - Cuperus - 2500.14989196
# Antwerpen - Sint-Paulusplaats - 654.230322053
# Antwerpen - Lange Van Bloerstraat - 2277.13671282
# Antwerpen - Van Ruusbroec - 2151.6332609
# Antwerpen - Balansstraat - 2038.76830793
# Antwerpen - Balansstraat - 2037.79573463
# Antwerpen - Montensstraat - 2257.17337061
# Antwerpen - Van Ruusbroec - 2064.68803411
# Borgerhout - Langstraat - 2211.71531321
# Borgerhout - Langstraat - 2265.58474991
# Antwerpen - Lente - 1729.90253046
# Antwerpen - Lente - 1769.66222908
# Antwerpen - P+R Linkeroever - 2822.11442313
# Antwerpen - P+R Linkeroever - 2826.12105604
# Antwerpen - P+R Linkeroever - 2826.12105604
# Antwerpen - P+R Linkeroever - 2812.60352522
# Antwerpen - Lokkaardstraat - 2353.94127444
# Antwerpen - F. Rooseveltplaats perron 44 - 954.286982487
# Antwerpen - Loosplaats - 1519.6384424
# Antwerpen - Loosplaats - 1378.60375615
# Antwerpen - Stadspark - 871.054612199
# Antwerpen - Halewijn - 1677.4165844
# Antwerpen - Halewijn - 1678.84116644
# Antwerpen - F. Rooseveltplaats perron 42 - 955.351968596
# Antwerpen - F. Rooseveltplaats perron 45 - 953.850955391
# Antwerpen - Markgravelei - 2553.87260779
# Antwerpen - Markgravelei - 2501.76483712
# Antwerpen - Markgravelei - 2498.96174056
# Antwerpen - Mechelseplein - 729.703905366
# Antwerpen - Mechelseplein - 707.669833772
# Antwerpen - Meirbrug - 186.236494641
# Antwerpen - Meirbrug - 155.846958944
# Antwerpen - Meirbrug - 162.201169107
# Antwerpen - Melkmarkt - 71.9400173804
# Antwerpen - Van Bree - 1241.71017173
# Borgerhout - Montensstraat - 2294.31922958
# Antwerpen - Museum - 1416.2305706
# Antwerpen - Museum - 1344.84712817
# Antwerpen - Nationale Bank - 978.661445239
# Antwerpen - Tunnelplaats - 1116.60993352
# Antwerpen - Tunnelplaats - 1118.09377716
# Antwerpen - Van Eedenplein - 1155.50011145
# Antwerpen - Nationale Bank - 980.442634568
# Antwerpen - Waaslandtunnel - 1921.37348453
# Antwerpen - Gijsselsstraat - 1816.53363329
# Antwerpen - Gijsselsstraat - 1779.39248932
# Antwerpen - Nationale Bank - 1003.87132958
# Antwerpen - Nationale Bank - 1008.48059921
# Antwerpen - Van Eedenplein - 1218.55887818
# Antwerpen - Verhaerenlaan - 1265.57985003
# Antwerpen - Verhaerenlaan - 1244.47069184
# Antwerpen - Stedelijk Lyceum - 1369.13604458
# Antwerpen - Stedelijk Lyceum - 1366.92818065
# Antwerpen - De Costerlaan - 1526.77652289
# Antwerpen - De Costerlaan - 1510.90711951
# Antwerpen - Farnèseplein - 1661.40298407
# Antwerpen - Farnèseplein - 1711.53471926
# Antwerpen - Gloriantlaan - 1871.3353698
# Antwerpen - Gloriantlaan - 1946.79391139
# Antwerpen - Noorderplaats - 1331.98292119
# Antwerpen - Sint-Annastrand - 2038.98793303
# Antwerpen - Van Velthemlaan - 2106.76896215
# Antwerpen - Van Velthemlaan - 2081.23926733
# Antwerpen - Hof Ter Schelde - 2292.35083353
# Antwerpen - Hof Ter Schelde - 2220.44926719
# Antwerpen - Vuylstekelaan - 2032.34401919
# Antwerpen - Vuylstekelaan - 2061.16600612
# Antwerpen - Vermeylenlaan - 1904.40004016
# Antwerpen - Station Zuid - 2678.91811556
# Antwerpen - Station Zuid - 2651.76562856
# Antwerpen - Station Zuid - 2587.7245761
# Antwerpen - Station Zuid - 2597.77050297
# Antwerpen - Ommeganck - 1480.57185072
# Antwerpen - Ommeganck - 1469.57814308
# Antwerpen - Van Helmontstraat - 2410.50679633
# Antwerpen - Lange Van Bloerstraat - 2267.34698436
# Antwerpen - Oosterweel-Kerk - 2892.14311867
# Antwerpen - Oosterweel-Kerk - 2876.15647359
# Borgerhout - Station Oost - 2911.36664716
# Borgerhout - Station Oost - 2876.25570309
# Antwerpen - Oudaan - 461.558362428
# Antwerpen - Premetrostation Groenplaats - 197.265232466
# Antwerpen - Premetrostation Groenplaats - 190.227804694
# Antwerpen - Hessenbrug - 726.02568305
# Antwerpen - Paardenmarkt - 937.931203029
# Antwerpen - Rodestraat - 876.906589749
# Antwerpen - PIVA - 2735.19336959
# Antwerpen - PIVA - 2652.82171818
# Antwerpen - Mercatorstraat - 1691.89331808
# Borgerhout - Plantin & Moretuslei - 2299.41651246
# Antwerpen - Plantin & Moretus - 1916.08898775
# Antwerpen - Plantin & Moretus - 1939.29815721
# Antwerpen - Plantin & Moretuslei - 2319.36961641
# Antwerpen - Ploeg - 1621.69686016
# Antwerpen - Ploeg - 1635.81778297
# Antwerpen - AZ Stuivenberg - 2281.20830632
# Antwerpen - Premetrostation Diamant - 1249.60051386
# Antwerpen - Premetrostation Diamant - 1270.84128809
# Antwerpen - Premetrostation Astrid - 1202.89985471
# Antwerpen - Premetrostation Astrid - 1207.77519185
# Antwerpen - Premetrostation Elisabeth - 1476.47811857
# Antwerpen - Premetrostation Meir - 250.616984536
# Antwerpen - Premetrostation Meir - 300.740957603
# Antwerpen - Premetrostation Elisabeth - 1472.49511696
# Antwerpen - Premetrostation Handel - 2087.43301302
# Antwerpen - Premetrostation Handel - 2107.89226068
# Antwerpen - Premetrostation Schijnpoort - 2615.77352183
# Antwerpen - Premetrostation Schijnpoort - 2596.18622339
# Antwerpen - Premetrostation Sport - 2945.28995006
# Antwerpen - Premetrostation Plantin - 1588.52153558
# Antwerpen - Premetrostation Plantin - 1634.70064173
# Antwerpen - Premetrostation Van Eeden - 1177.256709
# Antwerpen - Premetrostation Van Eeden - 1158.21495623
# Antwerpen - Premetrostation Sport - 2915.25693473
# Borgerhout - De Roma - 2730.08034285
# Antwerpen - Provinciehuis - 2418.50730411
# Antwerpen - Provinciehuis - 2412.56098612
# Antwerpen - Provinciehuis - 2574.88598254
# Antwerpen - Markgravelei - 2647.89324376
# Antwerpen - Van Den Nestlei - 1826.9532904
# Antwerpen - Quellin perron 1 - 950.41930271
# Borgerhout - Ranststraat - 2545.51515894
# Antwerpen - Richard - 1213.52998545
# Antwerpen - Rotterdamstraat - 1158.85845219
# Antwerpen - Royerssluis - 2443.62268766
# Antwerpen - Royerssluis - 2420.50782953
# Antwerpen - Rubenslei - 1038.29648891
# Berchem - Station perron 22 - 2942.90222871
# Antwerpen - Sanderusstraat - 1360.86795757
# Antwerpen - Sanderusstraat - 1398.85228702
# Antwerpen - Sint-Michielskaai - 1017.07903182
# Antwerpen - Sint-Michielskaai - 1040.59693784
# Antwerpen - Scheldestraat - 1088.21764356
# Antwerpen - Schijnpoort - 2641.49768187
# Antwerpen - Schijnpoort - 2611.32410749
# Antwerpen - Sint-Jansvliet - 619.67669227
# Antwerpen - Schijnpoort - 2650.05787157
# Antwerpen - Schijnpoort - 2688.03813626
# Antwerpen - Sporthal - 2462.89324548
# Antwerpen - Sporthal - 2461.70221498
# Deurne - Sportpaleis - 2981.15456998
# Antwerpen - Sint-Pietersvliet - 721.008050622
# Antwerpen - Sint-Elisabethstraat - 1476.97416567
# Antwerpen - Sint-Gummarus - 1402.71394481
# Antwerpen - Sint-Jacob - 428.146088994
# Antwerpen - Sint-Jacob - 441.593676492
# Antwerpen - Sint-Jansplein - 1110.55304344
# Antwerpen - Sint-Jansplein - 1109.9466589
# Antwerpen - Sint-Jansvliet - 606.680050972
# Antwerpen - Sint-Katelijne - 154.209600341
# Antwerpen - Sint-Pietersvliet - 666.276000721
# Antwerpen - Sint-Vincentius - 1644.7572049
# Antwerpen - Sint-Willibrorduskerk - 1985.82349381
# Antwerpen - Sint-Willibrorduskerk - 2009.4518975
# Berchem - Maatschappijstraat - 2836.6831162
# Berchem - Maatschappijstraat - 2828.73406311
# Antwerpen - Station Dam - 2065.52844566
# Antwerpen - Station Dam - 2068.81437724
# Borgerhout - Stenenbrug - 2927.46260416
# Borgerhout - Stenenbrug - 2909.01665651
# Antwerpen - AZ Stuivenberg - 2289.70279177
# Antwerpen - AZ Stuivenberg - 2340.66509512
# Antwerpen - AZ Stuivenberg - 2343.0972953
# Antwerpen - Stuivenberg - 1910.50331566
# Antwerpen - Stuivenberg - 1907.26621835
# Antwerpen - Suikerrui Steenplein - 477.477292139
# Antwerpen - Suikerrui Steenplein - 460.59943942
# Antwerpen - Sint-Andries - 508.07018502
# Antwerpen - Tavernierkaai - 851.509840204
# Borgerhout - Technisch Centrum - 2977.11625765
# Borgerhout - Turnhoutsebaan - 2903.29754711
# Borgerhout - Turnhoutsebaan - 2856.6870605
# Antwerpen - Mercatorstraat - 1622.13446098
# Antwerpen - Van Den Nestlei - 1763.67707268
# Antwerpen - Lamorinièrestraat - 2252.23512914
# Antwerpen - Kerkstraat - 1794.32630208
# Antwerpen - Van Helmontstraat - 2403.57524215
# Antwerpen - Van Luppenstraat - 2563.85107514
# Antwerpen - Cuperus - 2425.61956853
# Antwerpen - Tavernierkaai - 782.969838858
# Antwerpen - Van Schoonbekeplein - 807.154479757
# Antwerpen - Van Schoonbekestraat - 2039.98313999
# Antwerpen - Van Schoonbekestraat - 2134.82087314
# Antwerpen - Van Schoonbekestraat - 2371.87284198
# Antwerpen - Van Schoonbekestraat - 2389.7380874
# Antwerpen - Bres - 1509.18887446
# Antwerpen - Ballaarstraat - 1707.37204629
# Berchem - Van Luppenstraat - 2601.682189
# Antwerpen - Waterpoort - 1653.31830054
# Antwerpen - Weilandstraat - 2242.08862795
# Antwerpen - Keizerstraat - 213.837902852
# Antwerpen - Zurenborg - 2152.87158153
# Antwerpen - Zurenborgstraat - 2243.86599687
# Antwerpen - Troonplaats - 1952.1811813
# Antwerpen - Amerikalei - 1661.38320161
# Antwerpen - Brederodestraat - 2186.8330109
# Antwerpen - Brederodestraat - 2175.65377255
# Antwerpen - F. Rooseveltplaats perron 35 - 931.588538122
# Antwerpen - F. Rooseveltplaats perron 32 - 935.092985937
# Antwerpen - F. Rooseveltplaats perron 21 - 989.579370322
# Antwerpen - F. Rooseveltplaats perron 23 - 994.3165984
# Antwerpen - F. Rooseveltplaats perron 33 - 931.825474262
# Antwerpen - F. Rooseveltplaats perron 34 - 926.618767678
# Antwerpen - F. Rooseveltplaats perron 31 - 935.092985937
# Antwerpen - F. Rooseveltplaats perron 41 - 948.089745414
# Antwerpen - F. Rooseveltplaats perron 11 - 1027.53141661
# Antwerpen - F. Rooseveltplaats perron 13 - 1019.42288538
# Antwerpen - F. Rooseveltplaats perron 14 - 1019.42288538
# Antwerpen - F. Rooseveltplaats perron 12 - 1024.4705888
# Antwerpen - F. Rooseveltplaats perron 43 - 949.083813258
# Antwerpen - Centraal Station perron 1 - 1245.17930788
# Antwerpen - Centraal Station perron 5 - 1243.53738704
# Antwerpen - Rubenslei - 1092.46504961
# Antwerpen - Noorderplaats - 1341.46817251
# Borgerhout - Turnhoutsepoort - 2950.28862786
# Borgerhout - Turnhoutsepoort - 2898.21937248
# Antwerpen - F. Rooseveltplaats perron 24 - 1049.15775306
# Antwerpen - F. Rooseveltplaats perron 10 - 1025.46425775
# Antwerpen - F. Rooseveltplaats afstaphalte - 916.682964222
# Antwerpen - Loosplaats - 1482.85327596
# Antwerpen - Van Eedenplein perron 1b - 1164.08541327
# Antwerpen - Van Eedenplein perron 1a - 1178.11066524
# Antwerpen - Van Eedenplein perron 2 - 1188.05109362
# Antwerpen - Van Eedenplein perron 3 - 1168.17071147
# Antwerpen - Zielenslaan/Halewijnlaan - 1739.91287188
# Antwerpen - Waterhoenlaan - 1500.05673931
# Antwerpen - Pluvierstraat - 1786.84989513
# Antwerpen - Vlaams Hoofdlaan - 1641.25324729
# Antwerpen - Galgenweel - 2319.71056955
# Antwerpen - Sporthal Linkeroever - 2341.09900564
# Antwerpen - P+R Linkeroever - 2885.42148797
# Antwerpen - Waaslandtunnel - 1886.25715238
# Antwerpen - Zielenslaan/Halewijnlaan - 1738.72736686
# Antwerpen - Waterhoenlaan - 1528.49571617
# Antwerpen - Pluvierstraat - 1766.5398003
# Antwerpen - Vlaams Hoofdlaan - 1631.40173195
# Antwerpen - Galgenweel - 2306.44240046
